# %% [markdown]
# # VanArt Data Preprocessing

# %%
# import statements 
import pandas as pd

# %% [markdown]
# ### Load the 2 datasets

# %%
# load the datasets 
public_art_df = pd.read_csv('public-art.csv', sep=';')
public_art_artists_df = pd.read_csv('public-art-artists.csv', sep=';')

# %%
# show the dataset public_art_df
public_art_df
# Out:
#      RegistryID                                      Title of Work  \
# 0             8                                    Charles Bentall
# 1            19                                          Lovers II
# 2            21                 Captain John Deighton (Gassy Jack)
# 3            23                                   Untitled (mural)
# 4            25                                        Celebration
# ..          ...                                                ...
# 660         682                                        Trypophobia
# 661         685  We’re looking for People Who Like to Look for ...
# 662         688                                           Untitled
# 663         690                                 Floating (Eye)Land
# 664         691                                  Vancouver Special
#
#                                 ArtistProjectStatement                  Type  \
# 0                                                  NaN            Figurative
# ...

# %%
# show the dataset public_art_artists_df
public_art_artists_df
# Out:
#      ArtistID FirstName            LastName  \
# 0           2      Rick             Switzer
# 1           5    Joe Y.  Wai Architect, Inc
# 2           8  Franklin               Allen
# 3          59       Joe               David
# 4           9    Edward                 Apt
# ..        ...       ...                 ...
# 563       679    Lucien               Durey
# 564       687      Alex       Gru?nenfelder
# 565       690       Jem               Noble
# 566       693     Evann             Siebens
# 567       695   Jeffery               Chong
#
#                                              ArtistURL  \
# 0    https://covapp.vancouver.ca/PublicArtRegistry/...
# 1    https://covapp.vancouver.ca/PublicArtRegistry/...
# 2    https://covapp.vancouver.ca/PublicArtRegistry/...
# 3    https://covapp.vancouver.ca/PublicArtRegistry/...
# 4    https://covapp.vancouver.ca/PublicArtRegistry/...
# ..                                                 ...
# ...

# %% [markdown]
# ### Merge the 2 datasets

# %%
public_art_df.columns
# Out:
# Index(['RegistryID', 'Title of Work', 'ArtistProjectStatement', 'Type',
#        'Status', 'SiteName', 'SiteAddress', 'PrimaryMaterial', 'URL',
#        'PhotoURL', 'Ownership', 'Neighbourhood', 'LocationOnsite', 'Geom',
#        'Geo Local Area', 'DescriptionOfwork', 'Artists', 'PhotoCredits',
#        'YearOfInstallation', 'geo_point_2d'],
#       dtype='object')

# %%
public_art_artists_df.columns
# Out:
# Index(['ArtistID', 'FirstName', 'LastName', 'ArtistURL', 'Biography',
#        'Country', 'Photo', 'PhotoCredit', 'Website'],
#       dtype='object')

# %%
public_art_df.head()
# Out:
#    RegistryID                       Title of Work  \
# 0           8                     Charles Bentall
# 1          19                           Lovers II
# 2          21  Captain John Deighton (Gassy Jack)
# 3          23                    Untitled (mural)
# 4          25                         Celebration
#
#                               ArtistProjectStatement                  Type  \
# 0                                                NaN            Figurative
# 1                                                NaN            Figurative
# 2  The sculpture was commissioned by Larry Killam...  Memorial or monument
# 3                                                NaN                 Mural
# 4                                                NaN             Sculpture
#
#                Status                SiteName                     SiteAddress  \
# 0            In place           Bentall Bldg.              501 Burrard Street
# ...

# %%
public_art_artists_df.head()
# Out:
#    ArtistID FirstName            LastName  \
# 0         2      Rick             Switzer
# 1         5    Joe Y.  Wai Architect, Inc
# 2         8  Franklin               Allen
# 3        59       Joe               David
# 4         9    Edward                 Apt
#
#                                            ArtistURL  \
# 0  https://covapp.vancouver.ca/PublicArtRegistry/...
# 1  https://covapp.vancouver.ca/PublicArtRegistry/...
# 2  https://covapp.vancouver.ca/PublicArtRegistry/...
# 3  https://covapp.vancouver.ca/PublicArtRegistry/...
# 4  https://covapp.vancouver.ca/PublicArtRegistry/...
#
#                                            Biography Country Photo  \
# 0                                                NaN     NaN   NaN
# 1  Joe Y. Wai Architect, Inc. was established in ...  Canada   NaN
# 2  Franklin Allen works with the Corner Group Arc...     NaN   NaN
# 3  A renowned artist and carver in the Clayoquot ...  Canada   NaN
# ...
